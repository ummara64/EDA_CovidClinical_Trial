# %% [markdown]
# # Import pandas for EDA

# %%
import pandas as pd
# Out:
# C:\Users\Haier\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # 1. Read Dataset and Explore the dataset by checking shape, columns, see the first/last 'n' rows using head/tail. (n= 5,15,30)

# %% [markdown]
# # Read File

# %%
df = pd.read_csv("COVID clinical trials.csv")

# %% [markdown]
# # Top 15 rows of the DataFrame

# %%
df.head(15)
# Out:
#     Rank   NCT Number                                              Title  \
# 0      1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1      2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2      3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3      4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4      5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 5      6  NCT04516954          Convalescent Plasma for COVID-19 Patients
# 6      7  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 7      8  NCT04634214  The Severity of COVID 19 in Diabetes and Non-d...
# 8      9  NCT04602884  Early Detection of COVID-19 Using Breath Analysis
# 9     10  NCT04384588  COVID19-Convalescent Plasma for Treating Patie...
# 10    11  NCT04355897  CoVID-19 Plasma in Treatment of COVID-19 Patients
# 11    12  NCT04412265          Frailty in Elderly Patients With COVID-19
# ...

# %% [markdown]
# # Last 6 rows of the dataframe

# %%
df.tail(6)
# Out:
#       Rank   NCT Number                                              Title  \
# 5777  5778  NCT04574466  Scaling-up Psychological Interventions With Sy...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5779  5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5782  5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
#            Acronym              Status         Study Results  \
# 5777           NaN          Recruiting  No Results Available
# 5778           NaN          Recruiting  No Results Available
# 5779           NaN  Not yet recruiting  No Results Available
# 5780           NaN          Recruiting  No Results Available
# 5781  MindMyMindFU          Recruiting  No Results Available
# 5782           NaN  Not yet recruiting  No Results Available
#
# ...

# %% [markdown]
# # Numbers of rows and columns in the Dataframe

# %%
df.shape
# Out:
# (5783, 27)

# %% [markdown]
# # Column details/Names

# %%
df.columns.str.strip() #it will remove unnecessary spaces from the column names
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %% [markdown]
# # Column dataType

# %%
df["Rank"].dtypes
# Out:
# dtype('int64')

# %%
df["Enrollment"].dtypes
# Out:
# dtype('float64')

# %%
df["Completion Date"].dtypes
# Out:
# dtype('O')

# %% [markdown]
# # 2. Extract Key Insights
#     - There's one int(Rank) and float(Enrollment) column and rest all are string/object data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
# ...

# %%
#df["Locations"].unique()
df["Locations"].nunique()
# Out:
# 4255

# %% [markdown]
# # Statistical Summary of Numerical data

# %%
df.describe()
# Out:
#               Rank    Enrollment
# count  5783.000000  5.749000e+03
# mean   2892.000000  1.831949e+04
# std    1669.552635  4.045437e+05
# min       1.000000  0.000000e+00
# 25%    1446.500000  6.000000e+01
# 50%    2892.000000  1.700000e+02
# 75%    4337.500000  5.600000e+02
# max    5783.000000  2.000000e+07

# %% [markdown]
# ## Statistical Summary of object data

# %%
df.describe(include = "object")
# Out:
#          NCT Number                                              Title  \
# count          5783                                               5783
# unique         5783                                               5775
# top     NCT04785898  Study Assessing Vagus Nerve Stimulation in CoV...
# freq              1                                                  2
#
#          Acronym      Status         Study Results Conditions  \
# count       2480        5783                  5783       5783
# unique      2338          12                     2       3067
# top     COVID-19  Recruiting  No Results Available   COVID-19
# freq          47        2805                  5747        720
#
#                  Interventions Outcome Measures  \
# count                     4897             5748
# unique                    4337             5687
# top     Other: No intervention        Mortality
# freq                        32                5
#
# ...

# %% [markdown]
# # 3. Loc and iloc

# %% [markdown]
# ## Select all columns for the first clinical trial in the dataset.

# %%
df.iloc[0]
# Out:
# Rank                                                                       1
# NCT Number                                                       NCT04785898
# Title                      Diagnostic Performance of the ID Now™ COVID-19...
# Acronym                                                          COVID-IDNow
# Status                                                Active, not recruiting
# Study Results                                           No Results Available
# Conditions                                                           Covid19
# Interventions               Diagnostic Test: ID Now™ COVID-19 Screening Test
# Outcome Measures           Evaluate the diagnostic performance of the ID ...
# Sponsor/Collaborators                  Groupe Hospitalier Paris Saint Joseph
# Gender                                                                   All
# Age                                18 Years and older   (Adult, Older Adult)
# ...

# %% [markdown]
# ## Retrieve the Title and Status of the clinical trial with the NCT Number 'NCT04595136'.

# %% [markdown]
#     - First check if Value exists in the data

# %%
value = 'NCT04595136'
if value in df['NCT Number'].values:
    print(f"{value} exists in the DataFrame.")
# Out:
# NCT04595136 exists in the DataFrame.

# %%
df["NCT Number"]=="NCT04595136" #this will show us the index of the given NCT Number
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 5778    False
# 5779    False
# 5780    False
# 5781    False
# 5782    False
# Name: NCT Number, Length: 5783, dtype: bool

# %%
df.iloc[[1],[1,2,4]]
# Out:
#     NCT Number                                              Title  \
# 1  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
#
#                Status
# 1  Not yet recruiting

# %% [markdown]
# ### Get the Sponsor/Collaborators and Start Date for clinical trials that are Recruiting.

# %%
df.loc[:,["Sponsor/Collaborators","Start Date","Status"]][df["Status" ]== "Recruiting"]
# Out:
#                                   Sponsor/Collaborators         Start Date  \
# 2                          University of Milano Bicocca        May 7, 2020
# 4     Centre Hospitalier Régional d'Orléans|Centre d...        May 5, 2020
# 9     Fundacion Arturo Lopez Perez|Confederación de ...      April 7, 2020
# 10                                  The Christ Hospital     April 28, 2020
# 11                         University of Milano Bicocca     April 16, 2020
# ...                                                 ...                ...
# 5776  University of Pittsburgh|U.S. National Science...   October 26, 2020
# 5777                               University of Zurich    August 25, 2020
# 5778  University of Wisconsin, Madison|National Inst...     March 23, 2020
# 5780         University of Illinois at Urbana-Champaign  February 10, 2021
# 5781  Mental Health Services in the Capital Region, ...     March 22, 2021
#
#           Status
# 2     Recruiting
# 4     Recruiting
# ...

# %% [markdown]
# ### Select the first 5 rows and columns Title, Conditions, and Outcome Measures.

# %%
df.loc[:,['Title','Conditions', 'Outcome Measures']].head()
# Out:
#                                                Title  \
# 0  Diagnostic Performance of the ID Now™ COVID-19...
# 1  Study to Evaluate the Efficacy of COVID19-0001...
# 2  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3  The Role of a Private Hospital in Hong Kong Am...
# 4         Maternal-foetal Transmission of SARS-Cov-2
#
#                                           Conditions  \
# 0                                            Covid19
# 1                               SARS-CoV-2 Infection
# 2                                            covid19
# 3                                              COVID
# 4  Maternal Fetal Infection Transmission|COVID-19...
#
#                                     Outcome Measures
# 0  Evaluate the diagnostic performance of the ID ...
# 1  Change on viral load results from baseline aft...
# 2  A qualitative analysis of parenchymal lung dam...
# 3  Proportion of asymptomatic subjects|Proportion...
# 4  COVID-19 by positive PCR in cord blood and / o...

# %% [markdown]
# ### Find the Completion Date and URL for the last 3 clinical trials in the dataset.

# %%
df.loc[:,['Completion Date','URL']].tail(3)
# Out:
#         Completion Date                                          URL
# 5780          July 2021  https://ClinicalTrials.gov/show/NCT04740229
# 5781  December 31, 2022  https://ClinicalTrials.gov/show/NCT04804917
# 5782      February 2025  https://ClinicalTrials.gov/show/NCT04680000

# %% [markdown]
# # 4. Determine the missing values in the whole dataset and analyze missing values in each column.

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %% [markdown]
#     - There is missing data in multiple columns like
#         > Acronym
#         > Interventions
#         > Outcome Measures
#         > Phases
#         > Enrollment
#         > Study Designs
#         > Other IDs
#         > Start Date
#         > Primary Completion Date
#         > Completion Date
#         > Results First Posted
#         > Locations
#         > Study Documents

# %%
df[df["Acronym"].isnull()].head()
# Out:
#     Rank   NCT Number                                              Title  \
# 10    11  NCT04355897  CoVID-19 Plasma in Treatment of COVID-19 Patients
# 19    20  NCT04407585  Testing the Accuracy of a Digital Test to Diag...
# 30    31  NCT04403672  Performance Evaluation of RealDetect™ COVID-19...
# 34    35  NCT04691895              Gastrointestinal Symptoms in COVID-19
# 40    41  NCT04412486     COVID-19 Convalescent Plasma (CCP) Transfusion
#
#    Acronym                  Status         Study Results  \
# 10     NaN              Recruiting  No Results Available
# 19     NaN              Recruiting  No Results Available
# 30     NaN              Recruiting  No Results Available
# 34     NaN  Active, not recruiting  No Results Available
# 40     NaN              Recruiting  No Results Available
#
#                                            Conditions  \
# 10                                           COVID 19
# 19                                           Covid-19
# ...

# %%
df["Outcome Measures"].isnull().sum()
# Out:
# 35

# %%
df["Results First Posted"].isnull().sum()
# Out:
# 5747

# %% [markdown]
# # 5. Calculate the sum of duplicate rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 6. Solve following question by using conditional statements (10)

# %% [markdown]
# ### How many studies have an enrollment greater than a certain threshold?

# %%
df["Enrollment"].dtype
# Out:
# dtype('float64')

# %%
df["Enrollment"].nunique()
# Out:
# 962

# %%
df["Enrollment"].value_counts()
# Out:
# Enrollment
# 100.0     350
# 200.0     244
# 60.0      176
# 30.0      173
# 50.0      168
#          ...
# 686.0       1
# 1282.0      1
# 6420.0      1
# 506.0       1
# 716.0       1
# Name: count, Length: 962, dtype: int64

# %%
df[df["Enrollment"] > 1000].shape[0]
# Out:
# 911

# %% [markdown]
# ### How many clinical trials have 'No Results Available'?

# %%
sum(df["Study Results"] == "No Results Available")
# Out:
# 5747

# %% [markdown]
# ### How many clinical trials are in an "Completed" and "Recruiting" status?

# %%
sum(df["Status"].isin(["Completed","Recruiting"]))
# Out:
# 3830

# %% [markdown]
# ### How many clinical trials are related to 'COVID-19'?

# %%
sum(df["Acronym"] == 'COVID-19')
# Out:
# 47

# %% [markdown]
# ### How many clinical trials started after January 1, 2020?

# %%
sum(df["Start Date"] == 'January 1, 2020')
# Out:
# 22

# %% [markdown]
# # The End
